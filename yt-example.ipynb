# %%
import yt
ds = yt.load("/home/astrosun/rixinli/runs/JT/PrelimProductRun/JTrunII_Acc/ppd_cyl.out1.00146.athdf")
print(ds.field_list) # available fields in the dataset
# Out:
# yt : [WARNING  ] 2023-04-30 18:17:52,200 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2023-04-30 18:17:52,202 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2023-04-30 18:17:52,202 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2023-04-30 18:17:52,203 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2023-04-30 18:17:52,256 Parameters: current_time              = 917.3449
# yt : [INFO     ] 2023-04-30 18:17:52,256 Parameters: domain_dimensions         = [ 256 1536    1]
# yt : [INFO     ] 2023-04-30 18:17:52,257 Parameters: domain_left_edge          = [ 0.40000001 -3.14159274 -0.5       ]
# yt : [INFO     ] 2023-04-30 18:17:52,258 Parameters: domain_right_edge         = [1.60000002 3.14159274 0.5       ]
# yt : [INFO     ] 2023-04-30 18:17:52,258 Parameters: cosmological_simulation   = 0
# [('athena_pp', 'dens'), ('athena_pp', 'mom1'), ('athena_pp', 'mom2'), ('athena_pp', 'mom3')]

# %%
yt.plot_2d(ds,("athena_pp","dens"),center=(1.,0)).set_log(("athena_pp","dens"),False)
# Out:
# yt : [INFO     ] 2023-04-30 18:18:31,629 xlim = 0.400000 1.600000
# yt : [INFO     ] 2023-04-30 18:18:31,630 ylim = -3.141593 3.141593
# yt : [INFO     ] 2023-04-30 18:18:31,632 Setting origin='native' for cylindrical geometry.
# yt : [INFO     ] 2023-04-30 18:18:31,633 xlim = 0.400000 1.600000
# yt : [INFO     ] 2023-04-30 18:18:31,634 ylim = -3.141593 3.141593
# yt : [INFO     ] 2023-04-30 18:18:31,635 Making a fixed resolution buffer of (('athena_pp', 'dens')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
yt.plot_2d(ds,("athena_pp","dens"),aspect=1,center=(1.,0),width=0.05).set_log(("athena_pp","dens"),False)
# Out:
# yt : [INFO     ] 2023-04-30 18:18:34,806 xlim = 0.975000 1.025000
# yt : [INFO     ] 2023-04-30 18:18:34,807 ylim = -0.025000 0.025000
# yt : [INFO     ] 2023-04-30 18:18:34,807 Setting origin='native' for cylindrical geometry.
# yt : [INFO     ] 2023-04-30 18:18:34,808 xlim = 0.975000 1.025000
# yt : [INFO     ] 2023-04-30 18:18:34,808 ylim = -0.025000 0.025000
# yt : [INFO     ] 2023-04-30 18:18:34,809 Making a fixed resolution buffer of (('athena_pp', 'dens')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
