# %%
import scipy as sp
import scipy.interpolate
import scipy.optimize
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import colors
from matplotlib import logging
import athplot
import numpy as np
import os
import importlib
os.chdir("/home/astrosun/jtlaune/athena/")
from mpl_styles import analytic
# %matplotlib widget
import yt
yt.set_log_level("error")
importlib.reload(athplot)
logging.getLogger('matplotlib.font_manager').disabled = True
import sys
sys.path.insert(0, "/home/astrosun/jtlaune/athena/vis/python/")
import athena_read as athr

# %%
# takes 4 mins
file = "/home/astrosun/jtlaune/Type1BCs/type1_accrete/ppd_cyl.hst"
hst = np.loadtxt(file,usecols=(0,1,13))

# %%
from matplotlib.ticker import AutoMinorLocator

# %%
t = hst[:,0]/(2*np.pi)
dt = hst[:,1]/(2*np.pi)
mdot = hst[:,2]
with mpl.rc_context(analytic): fig, ax = plt.subplots(figsize=(7,5))
ax.plot(t,mdot,c="k")
ax.set_xlabel(r"$t/(2\pi\Omega_0)$")
ax.set_ylabel(r"$\dot m/(M\Omega_0)$")
ax.set_ylim((0,0.0004))
ax.set_xlim(0,100)
fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Torques

# %%
# takes 8 mins
#file = "/home/astrosun/jtlaune/Type1BCs/type1_accrete/ppd_cyl.hst"
file = "/home/astrosun/jtlaune/athena/work/type2-linext/hires/accrete/ppd_cyl.hst"
hst = np.loadtxt(file,usecols=(0,1,10,12,15))

# %%
#takes 5 secs
#file = "/home/astrosun/jtlaune/Type1BCs/type1_fiducial/ppd_cyl.hst"
file = "/home/astrosun/jtlaune/athena/work/type2-linext/hires/no_accrete/ppd_cyl.hst"
hstFid = np.loadtxt(file,usecols=(0,1,10,12,15))

# %%
hstFid
# Out:
# array([[ 0.00000e+00,  2.16371e-04,  0.00000e+00, -5.42101e-20,
#          0.00000e+00],
#        [ 2.16371e-04,  2.16371e-04,  0.00000e+00,  5.56603e-13,
#          0.00000e+00],
#        [ 4.32743e-04,  2.16371e-04,  0.00000e+00,  1.08095e-12,
#          0.00000e+00],
#        ...,
#        [ 6.28318e+02,  8.81964e-05,  0.00000e+00, -2.50311e-06,
#          0.00000e+00],
#        [ 6.28318e+02,  5.92987e-05,  0.00000e+00, -2.50311e-06,
#          0.00000e+00],
#        [ 6.28319e+02,  8.81978e-05,  0.00000e+00, -2.50306e-06,
#          0.00000e+00]])

# %%
hst.shape
# Out:
# (52378505, 5)

# %%
q = 1e-4
h = 0.05
G0 = q**2/h**2
t = hst[::50,0]/(2*np.pi)
tFid = hstFid[::50,0]/(2*np.pi)
dt = hst[::50,1]/(2*np.pi)
Ptorq = hst[::50,2]/G0
Gtorq = hst[::50,3]/G0
momtorq = hst[::50,4]/G0
torq = hstFid[::50,3]/G0
with mpl.rc_context(analytic): fig, ax = plt.subplots(figsize=(7,5))
ax.plot(t,Gtorq+Ptorq+momtorq,c="r",ls="-",label="Acc. total")
ax.plot(t,Gtorq,c="r",ls="--",label="Acc. grav")
ax.plot(t,Ptorq,c="r",ls=":",label="Acc. pressure")
ax.plot(t,momtorq,c="r",ls="-.",label="Acc. gas mom.")
ax.plot(tFid,torq,c="k",label="Fid. grav")
ax.set_xlabel(r"$t/(2\pi\Omega_0)$")
ax.set_ylabel(r"$\Gamma/\Gamma_0$")
#ax.set_ylim((-10,10))
ax.set_yscale("symlog",linthresh=1e-1)
ax.set_xlim(0,100)
ax.legend(bbox_to_anchor=[1.0, 1.0, 0, 0])
fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# /home/astrosun/jtlaune/opt/miniconda3/envs/py311/lib/python3.11/site-packages/ipympl/backend_nbagg.py:279: UserWarning: All values for SymLogScale are below linthresh, making it effectively linear. You likely should lower the value of linthresh.
#   self.manager.handle_json(content)

# %%
ax.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
t = hst[:,0]/(2*np.pi)
dt = hst[:,1]/(2*np.pi)
mdot = hst[:,2]
with mpl.rc_context(analytic): fig, ax = plt.subplots()
ax.plot(t,mdot,c="k")
ax.set_xlabel(r"$t/(2\pi\Omega_0)$")
ax.set_ylabel(r"$\dot m/(M\Omega_0)$")
ax.set_ylim(bottom=0)
ax.set_xlim(0,100)
fig.tight_layout()

# %% [markdown]
# ## mdot

# %%
file = "/home/astrosun/jtlaune/athena/work/type2-linext/hires/accrete/ppd_cyl.hst"
hst = np.loadtxt(file,usecols=(0,1,13,))
t = hst[:,0]/(2*np.pi)
dt = hst[:,1]/(2*np.pi)
mdot = hst[:,2]
with mpl.rc_context(analytic): fig, ax = plt.subplots()
ax.plot(t,mdot,c="k")
ax.set_xlabel(r"$t/(2\pi\Omega_0)$")
ax.set_ylabel(r"$\dot m/(M\Omega_0)$")
ax.set_ylim(bottom=0)
ax.set_xlim(0,100)
fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Mesh

# %%
# %run -i vis/python/plot_mesh.py -i work/smr5_noAcc/mesh_structure.dat -o show
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## 2D plots

# %%
importlib.reload(athplot)
filename = "/home/astrosun/jtlaune/athena/work/type2-linext/q1e-4_nu1e-4/accrete_rst/ppd_cyl.out1.00586.athdf"
ds_raw = athr.athdf(
    filename,
    raw=True,
)
Nmb = ds_raw["NumMeshBlocks"]
ccr = np.zeros((Nmb, 96 * 16))
ccphi = np.zeros((Nmb, 96 * 16))
for imb in range(Nmb):
    x1v = ds_raw["x1v"][imb, :]
    x2v = ds_raw["x2v"][imb, :]
    x1v, x2v = np.meshgrid(x1v, x2v)
    x1v, x2v = x1v.flatten(), x2v.flatten()
    ccr[imb, :] = x1v
    ccphi[imb, :] = x2v
ccr, ccphi = ccr.flatten(), ccphi.flatten()
print(ccr.shape, ccphi.shape)
print(ds_raw["x1v"].shape)
print(ds_raw["x2v"].shape)
print(ds_raw["dens"].shape)
ccdens = ds_raw["dens"][:, 0, :, :].flatten()
ccmom1 = ds_raw["mom1"][:, 0, :, :].flatten()
ccmom2 = ds_raw["mom2"][:, 0, :, :].flatten()

# r1, r2 = np.min(ccr), np.max(ccr)
# phi1, phi2 = np.min(ccphi), np.max(ccphi)

r1, r2 = 0.85, 1.15
phi1, phi2 = -0.5, 0.5

rr, pp = np.linspace(r1, r2, 1000), np.linspace(phi1, phi2, 1000)
RR, PP = np.meshgrid(rr, pp)
DENS = sp.interpolate.griddata((ccr, ccphi), ccdens, (RR, PP), method="nearest")
V1 = sp.interpolate.griddata((ccr, ccphi), ccmom1 / ccdens, (RR, PP), method="nearest")
V2 = sp.interpolate.griddata((ccr, ccphi), ccmom2 / ccdens, (RR, PP), method="nearest")
plt.clf()
plt.figure(figsize=(5,10))
plt.streamplot(RR, PP, V1, V2, color="k", linewidth=0.5)
plt.xlabel(r"$r/R_0$", fontsize=24)
plt.ylabel(r"$\phi$", fontsize=24)
plt.tick_params("both", labelsize=24)
circle2 = plt.Circle((1, 0), 0.00322, color="c", fill=False)
plt.gca().add_patch(circle2)
plt.title(
    r"Accretor, Type II"
    + "\n"
    + r"$q=10^{-4}$, $\nu=10^{-4}$,"
    + "\n"
    + r"$h$=0.1, $x_s$=0.0531"
    + "\n"
    + r"b=0",
    fontsize=24,
)
plt.xlim(r1,r2)
plt.ylim(phi1,phi2)
plt.tight_layout()
plt.show()
# Out:
# (172032,) (172032,)
# (112, 16)
# (112, 96)
# (112, 1, 96, 16)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
112*96*16
# Out:
# 172032

# %%
importlib.reload(athplot)
ds = athplot.rawDataRestricted("/home/astrosun/jtlaune/athena/work/type1/q1e-4_nu1e-4/accrete/ppd_cyl.out1.00400.athdf")
with mpl.rc_context(analytic):
    fig, ax = plt.subplots(figsize=(5, 8))
    for lev in range(3,4):
        cccs, lds = ds.get_level(
            lev
        )  # meaning: cell center coordinates, level data set
        meshr, meshphi = np.meshgrid(cccs[0], cccs[1])
        im = ax.pcolormesh(
            #meshr * np.cos(meshphi),
            #meshr * np.sin(meshphi),
            meshr,
            meshphi,
            lds["dens"],
            shading="nearest",
            cmap="inferno",
            norm=colors.LogNorm(vmin=0.1, vmax=10.0),
        )
    cb = plt.colorbar(im, label=r"$\Sigma/\Sigma_0$")
    ax.set_ylabel(r"$Y$", fontsize=24)
    ax.set_xlabel(r"$X$", fontsize=24)
    ax.tick_params("x", rotation=90)
    #ax.set_aspect(1)
    fig.subplots_adjust(bottom=0.2)
    #ax.set_xlim((0.964,1.036))
    #ax.set_ylim((-0.036,.036))
    # fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
circle2 = plt.Circle((1, 0), 0.00204, color='c', fill=False)
ax.add_patch(circle2)

# %%
importlib.reload(athplot)
ds = athplot.rawDataRestricted("/home/astrosun/jtlaune/athena/work/m-wave/testing/ppd_cyl.out1.00100.athdf")
fig, ax = plt.subplots(figsize=(4, 7))
for lev in range(1):
    cccs, lds = ds.get_level(lev) # meaning: cell center coordinates, level data set
    meshr, meshphi = np.meshgrid(cccs[0], cccs[1])
    im = ax.pcolormesh(meshr, meshphi, lds['dens'], shading='nearest', cmap="inferno", norm=colors.LogNorm(vmin=0.9, vmax=1.11))
cb = plt.colorbar(im)
cb.ax.set_ylabel(r"$\Sigma/\Sigma_0$",rotation=270,fontsize=24)
ax.set_title(r"$m=2$ $A=10^{-4}$ $T=50$ orb")
ax.set_ylabel(r"$\phi$",fontsize=24)
ax.set_xlabel(r"$r$",fontsize=24)
fig.tight_layout()
plt.auto
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
(1e-3/3)**(1./3)
# Out:
# 0.06933612743506348

# %%
0.6**(2./3)
# Out:
# 0.7113786608980126

# %%
(1/0.7113786608980126)**(3./2)
# Out:
# 1.6666666666666665

# %%
1.9/1.6*768
# Out:
# 911.9999999999998

# %%
32*28/2
# Out:
# 448.0

# %%
628.318530718*2
# Out:
# 1256.637061436

# %%
1e-4/0.1**2
# Out:
# 0.009999999999999998

# %%
0.05*(1e-4/3)**(1./3)
# Out:
# 0.0016091489743427169

# %%
0.00161+0.00043
# Out:
# 0.00204

# %%
(0.05*(1e-4/3)**(1./3))/(1.2/128/2**4)
# Out:
# 2.7462809162115702

# %%
(1e-4/3)**(1./3)/0.05
# Out:
# 0.6436595897370867

# %%
(1e-4/3)**(1./3)*0.6
# Out:
# 0.019309787692112602

# %%
1.68*np.sqrt(1e-4/0.05)
# Out:
# 0.07513188404399293

# %%
print(np.sqrt(8*1e-4/3/0.0193))
# Out:
# 0.11754541987684666

# %%
(0.0751/0.0531)**4
# Out:
# 4.001120800870568

# %%
print(8*np.pi/3/0.0531)
print(8*np.pi/3/0.0751)
# Out:
# 157.76987588649305
# 111.55233568006366

# %%
print(1.2/128/2**4)
print(2*np.pi/768/2**4)
# Out:
# 0.0005859375
# 0.0005113269292952137

# %%
0.1**2/1e-4
# Out:
# 100.00000000000001

# %%
628.318530718*3
# Out:
# 1884.955592154

# %% [markdown]
# ## Torque magnitudes over time

# %%
hst = np.loadtxt("/home/astrosun/jtlaune/athena/work/type1/q1e-4_nu1e-4/accrete/ppd_cyl.hst")
hst3 = np.loadtxt("/home/astrosun/jtlaune/athena/work/type1/q1e-4_nu1e-4/accrete_soft/ppd_cyl.hst")
hst2 = np.loadtxt("/home/astrosun/jtlaune/athena/work/type1/q1e-4_nu1e-4/accrete_0.05rh/ppd_cyl.hst")
hst1 = np.loadtxt("/home/astrosun/jtlaune/athena/work/type1/q1e-4_nu1e-4/fiducial/ppd_cyl.hst")

#hst = np.loadtxt("/home/astrosun/jtlaune/athena/work/type1/accrete/ppd_cyl.hst")
#hst1 = np.loadtxt("/home/astrosun/jtlaune/athena/work/type1/fiducial/ppd_cyl.hst")

#hst = np.loadtxt("/home/astrosun/jtlaune/athena/work/type2-linext/q1e-4_nu1e-4/accrete_rst/ppd_cyl.hst")
#hst1 = np.loadtxt("/home/astrosun/jtlaune/athena/work/type2-linext/q1e-4_nu1e-4/fiducial/ppd_cyl.hst")
#hst2 = np.loadtxt("/home/astrosun/jtlaune/athena/work/type2-linext/q1e-4_nu1e-4/accrete_rst_0.05rh/ppd_cyl.hst")
#hst3 = np.loadtxt("/home/astrosun/jtlaune/athena/work/type2-linext/q1e-4_nu1e-4/accrete_rst_soft/ppd_cyl.hst")

#hst = np.loadtxt("/home/astrosun/jtlaune/athena/work/type1/q1e-4_nu1e-4_h0.05/fiducial/ppd_cyl.hst")
#hst1 = np.loadtxt("/home/astrosun/jtlaune/athena/work/type1/q1e-4_nu1e-4_h0.05/accrete_rst/ppd_cyl.hst")

# %%
plt.clf()
plt.plot(hst[:,0],hst[:,12]/(1e-4/0.1)**2  ,label="accrete")
plt.plot(hst1[:,0],hst1[:,12]/(1e-4/0.1)**2,label="fiducial")
plt.plot(hst2[:,0],hst2[:,12]/(1e-4/0.1)**2,label="accrete 0.05rh")
plt.plot(hst3[:,0],hst3[:,12]/(1e-4/0.1)**2,label="accrete_soft")
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(np.average(hst1[:,12][-100:])/(1e-4/0.1)**2)
# Out:
# -0.8461507

# %%
mpl.rcParams["axes.linewidth"] = 2
mpl.rcParams["ytick.minor.size"]=3
mpl.rcParams["ytick.minor.width"]=1
mpl.rcParams["xtick.minor.size"]=3
mpl.rcParams["xtick.minor.width"]=1
mpl.rcParams["ytick.direction"]="in"
mpl.rcParams["xtick.direction"]="in"
mpl.rcParams["ytick.major.size"]=5
mpl.rcParams["ytick.major.width"]=1
mpl.rcParams["figure.facecolor"]="FFFFFF"
mpl.rcParams["ytick.left"]=True
mpl.rcParams["ytick.right"]=True
mpl.rcParams["xtick.top"]=True
mpl.rcParams["xtick.bottom"]=True
mpl.rcParams["axes.grid.which"]="both"
mpl.rcParams["axes.titlesize"]= 20
mpl.rcParams["xtick.labelsize"]= 24
mpl.rcParams["ytick.labelsize"]= 24
mpl.rcParams["font.family"] = "serif"
mpl.rcParams["grid.linewidth"] = 0.4
mpl.rcParams["grid.alpha"] = 0.4

# %%
def formatter(f,x,pos, thresh):
    if x == thresh:
        return r"$\pm$"+f(x,pos)
    else:
        return f"-{f(x,pos)}"

# %%
import matplotlib.ticker
fig, axes = plt.subplots(2,figsize=(8,7))
ax = axes[0]
ax.plot(hst[:,0]/(2*np.pi),(hst[:,15]+hst[:,10]+hst[:,12])/(1e-4/0.1)**2,c="r",ls="-",label="Accretor total")
ax.plot(hst[:,0]/(2*np.pi),(hst[:,15])/(1e-4/0.1)**2,c="r",ls="--",label="Accreted y-momentum")
ax.plot(hst[:,0]/(2*np.pi),(hst[:,10])/(1e-4/0.1)**2,c="r",ls=":",label="Pressure")

ax.plot(hst2[:,0]/(2*np.pi),(hst2[:,15]+hst2[:,10]+hst2[:,12])/(1e-4/0.1)**2,c="g",ls="-",label="Accretor total")
ax.plot(hst2[:,0]/(2*np.pi),(hst2[:,12])/(1e-4/0.1)**2,ls="-.",c="g",label="Gravity")
ax.plot(hst2[:,0]/(2*np.pi),(hst2[:,15])/(1e-4/0.1)**2,c="g",ls="--",label="Accreted y-momentum")

#ax.axhline(y=0.84705787,ls="--",lw=3)
#ax.plot(hst1[:,0],-hst1[:,12]/(1e-4/0.1)**2)
ax.set_ylim(0.01,70)
ax.xaxis.set_tick_params(labelbottom=False)
ax.tick_params(which="both",labelsize=24)

ax = axes[1]
ax.tick_params(which="both",labelsize=24)
ax.plot(0,0,c="0.8",ls="-",label="Accretor total")
ax.plot(0,0,c="0.8",ls="--",label="Accreted y-momentum")
ax.plot(0,0,c="0.8",ls=":",label="Pressure")
ax.plot(0,0,c="0.8",ls="-.",label="Gravity")

ax.plot(hst2[:,0]/(2*np.pi),-(hst2[:,10])/(1e-4/0.1)**2,c="g",ls=":",label="Pressure")

ax.set_ylim(5,0.01)
ax.plot(hst[:,0]/(2*np.pi),-(hst[:,12])/(1e-4/0.1)**2,ls="-.",c="r")#,label="Gravity")
ax.plot(hst1[:,0]/(2*np.pi),-(hst1[:,12])/(1e-4/0.1)**2,c="k",label="Fiducial total")
ax.legend()

for ax in axes:
    ax.yaxis.set_minor_locator(mpl.ticker.LogLocator(numticks=11))
    ax.set_yscale("log")
    ax.set_xlim(0,200)

f = axes[1].yaxis.get_major_formatter()
axes[1].yaxis.set_major_formatter(lambda x, pos: formatter(f,x,pos,0.01))
fig.supylabel(r"$\Gamma/\Gamma_0$",fontsize=24)
axes[1].set_xlabel(r"$t$ [$2\pi/\Omega_0$]",fontsize=24)
fig.tight_layout()
fig.subplots_adjust(hspace=0)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import matplotlib.ticker
fig, ax = plt.subplots(figsize=(7,5))
ax.plot(hst[:,0]/(2*np.pi),hst[:,13],c="r",ls="-")
ax.set_xlim(0,200)
ax.set_ylim(bottom=0)
ax.set_ylabel(r"$\dot M$",fontsize=24)
ax.set_xlabel(r"t [$2\pi/\Omega_0$]",fontsize=24)
ax.set_title(r"Type 1")
fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
importlib.reload(athplot)
hstAcc = athplot.athhst(1e-3,"/home/astrosun/jtlaune/athena/work/type2-linext/hires/accrete/ppd_cyl.hst")
hstNoAcc = athplot.athhst(1e-3,"/home/astrosun/jtlaune/athena/work/type2-linext/hires/no_accrete/ppd_cyl.hst")

fig, ax = hstAcc.plotSmoothTorq("Acc.",1,symlog=True,linthresh=1e-6,c="r",ct="r",step=1,ybds=(-1e-3,5e-3))
hstNoAcc.plotSmoothTorq("Fid.",1,symlog=True,linthresh=1e-6,c="k",ct="k",step=1,ybds=(-1e-3,5e-3),figax=(fig,ax))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[72], line 5
#       2 hstAcc = athplot.athhst(1e-3,"/home/astrosun/jtlaune/athena/work/type2-linext/hires/accrete/ppd_cyl.hst")
#       3 hstNoAcc = athplot.athhst(1e-3,"/home/astrosun/jtlaune/athena/work/type2-linext/hires/no_accrete/ppd_cyl.hst")
# ----> 5 fig, ax = hstAcc.plotSmoothTorq("Acc.",1,symlog=True,linthresh=1e-6,c="r",ct="r",step=1,ybds=(-1e-3,5e-3))
#       6 hstNoAcc.plotSmoothTorq("Fid.",1,symlog=True,linthresh=1e-6,c="k",ct="k",step=1,ybds=(-1e-3,5e-3),figax=(fig,ax))
#
# AttributeError: 'athhst' object has no attribute 'plotSmoothTorq'

# %%
with mpl.rc_context(analytic): fig, ax = plt.subplots()
totAcc = hstAcc.FP_y + hstAcc.momy_accrate + hstAcc.Fsgrav_y
ax.plot(hstAcc.t, athplot.movingAverage(totAcc,24)/athplot.movingAverage(hstNoAcc.Fsgrav_y,24))
ax.set_yscale("log")
ax.set_ylim((0.9,2))
fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Density profiles over time

# %%
data_dir = "/home/astrosun/jtlaune/athena/work/smr4_noPlanet/"
with mpl.rc_context(analytic): fig, ax = plt.subplots()
for iout in [0,10,20,50,100,200]:
    data_file = os.path.join(data_dir,f"ppd_cyl.out1.{iout:05}.athdf")
    hdf5 = athplot.PpdCylAthhdf5(1e-3,(64,384),data_file)
    profs = hdf5.reduce(data_dir)
    ax.plot(profs["rMidpts"],profs["Sig"])
    ax.set_xlim((profs["rMidpts"][0],profs["rMidpts"][-1]))
ax.set_yscale("log")

# %%
data_dir = "/home/astrosun/jtlaune/athena/work/smr4/"
with mpl.rc_context(analytic): fig, ax = plt.subplots()
for iout in [0,10,20,50,100,200]:
    data_file = os.path.join(data_dir,f"ppd_cyl.out1.{iout:05}.athdf")
    hdf5 = athplot.PpdCylAthhdf5(1e-3,(64,384),data_file)
    profs = hdf5.reduce(data_dir)
    ax.plot(profs["rMidpts"],profs["Sig"])
    ax.set_xlim((profs["rMidpts"][0],profs["rMidpts"][-1]))
ax.set_yscale("log")

# %%
data_dir = "/home/astrosun/jtlaune/athena/work/smr4_noAcc/"
with mpl.rc_context(analytic): fig, ax = plt.subplots()
for iout in [0,10,20,50,100,200]:
    data_file = os.path.join(data_dir,f"ppd_cyl.out1.{iout:05}.athdf")
    hdf5 = athplot.PpdCylAthhdf5(1e-3,(64,384),data_file)
    profs = hdf5.reduce(data_dir)
    ax.plot(profs["rMidpts"],profs["Sig"])
    ax.set_xlim((profs["rMidpts"][0],profs["rMidpts"][-1]))
ax.set_yscale("log")

# %%
1.468/2
# Out:
# 0.734

# %% [markdown]
# ## Density profiles

# %%
mRing = {}
SigProf = {}
vrMassAvg = {}
Mdot = {}
vrdmRing = {}
SigdmRing = {}

# %%
for iout in np.arange(40,61,2)*10:
    file = f"/home/astrosun/jtlaune/athena/work/type2-linext/q1e-4_nu1e-4/fiducial/ppd_cyl.out1.{iout:05}.athdf"
    ds = yt.load(file)
    dd = ds.all_data()
    dens_data = np.array(dd["athena_pp", "dens"])
    vr_data = np.array(dd["athena_pp", "mom1"]) / dens_data
    vphi_data = np.array(dd["athena_pp", "mom2"]) / dens_data
    # coords are cell-centered
    coords = np.array(dd.fcoords)
    # widths of cells
    fwidths = np.array(dd.fwidth)
    Nr = 128

    ristart = 0
    riend = Nr + 1
    rEdges = np.linspace(0.4, 1.6, riend, endpoint=True)
    rMids = (rEdges[:-1] + rEdges[1:]) / 2

    mRing[iout] = np.zeros(Nr)
    vrdmRing[iout] = np.zeros(Nr)
    SigdmRing[iout] = np.zeros(Nr)

    for i in range(len(dens_data)):
        Sig = dens_data[i]
        vr = vr_data[i]
        vphi = vphi_data[i]
        r = coords[i, 0]
        phi = coords[i, 1]
        for j in range(Nr+1):
            if rEdges[j] < r <= rEdges[j + 1]:
                rsecn = np.sqrt(r**2 + 1 - 2 * r * np.cos(phi))
                x = r * np.cos(phi)
                y = r * np.sin(phi)

                dr = fwidths[i, 0]
                dphi = fwidths[i, 1]
                dA = r * dr * dphi
                dm = Sig*dA

                mRing[iout][j] += dm
                vrdmRing[iout][j] += vr*dm
                SigdmRing[iout][j] += Sig*dm

    SigProf[iout] = mRing[iout] / (2 * np.pi * rMids[:] * np.diff(rEdges)[:])
    vrMassAvg[iout] = vrdmRing[iout] / mRing[iout]
    Mdot[iout] = 2*np.pi*rMids*vrMassAvg[iout]*SigProf[iout]

# %%
with mpl.rc_context(analytic): fig, ax = plt.subplots(figsize=(7,5))
for iout in np.arange(40,61,2)*10:
    ax.plot(rMids,SigProf[iout],label=f"{int(iout/2)} orbits")    
ax.set_ylabel(r"$\Sigma/\Sigma_0$",fontsize=24)
ax.set_xlabel(r"$r/R_0$",fontsize=24)
ax.legend()
#ax.set_yscale("log")
ax.set_xlim((0.4,1.6))
ax.set_title(r"Fiducial Type 2 $q=10^{-4}$ $\nu=10^{-4}$")
fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
with mpl.rc_context(analytic): fig, ax = plt.subplots(figsize=(7,5))
for iout in np.arange(40,61,2)*10:
    ax.plot(rMids,Mdot[iout],label=f"{int(iout/2)} orbits")    
ax.set_ylabel(r"$\dot M$",fontsize=24)
ax.set_xlabel(r"$r/R_0$",fontsize=24)
ax.legend()
#ax.set_yscale("log")
ax.set_xlim((0.4,1.6))
ax.set_title(r"Fiducial Type 2 $q=10^{-4}$ $\nu=10^{-4}$")
fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
with mpl.rc_context(analytic): fig, ax = plt.subplots(figsize=(7,5))
for iout in np.arange(17)*100:
    ax.scatter(iout,np.min(SigProf[iout]),c="k")
ax.set_yscale("log")
ax.set_ylim(0.5,1)
ax.tick_params("x", rotation=90)
ax.set_xlabel(r"orbit")
ax.set_ylabel(r"$\min(\Sigma(r))$")
fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## $\dot J$ profile

# %%
file = "/home/astrosun/jtlaune/athena/work/type2-linext/q1e-4_nu1e-4/no_planet/ppd_cyl.out1.00600.athdf"
ds = yt.load(file)
dd = ds.all_data()
dens_data = np.array(dd["athena_pp", "dens"])
vr_data = np.array(dd["athena_pp", "mom1"]) / dens_data
vphi_data = np.array(dd["athena_pp", "mom2"]) / dens_data
# coords are cell-centered
coords = np.array(dd.fcoords)
# widths of cells
fwidths = np.array(dd.fwidth)
Nr = 128

ristart = 0
riend = Nr + 1
rEdges = np.linspace(0.4, 1.6, riend, endpoint=True)
rMids = (rEdges[:-1] + rEdges[1:]) / 2

mRing = np.zeros(Nr)
vrdmRing = np.zeros(Nr)
vpdmRing = np.zeros(Nr)
SigdmRing = np.zeros(Nr)

for i in range(len(dens_data)):
    Sig = dens_data[i]
    vr = vr_data[i]
    vphi = vphi_data[i]
    r = coords[i, 0]
    phi = coords[i, 1]
    for j in range(Nr + 1):
        if rEdges[j] < r <= rEdges[j + 1]:
            rsecn = np.sqrt(r**2 + 1 - 2 * r * np.cos(phi))
            x = r * np.cos(phi)
            y = r * np.sin(phi)

            dr = fwidths[i, 0]
            dphi = fwidths[i, 1]
            dA = r * dr * dphi
            dm = Sig * dA

            mRing[j] += dm
            vrdmRing[j] += vr * dm
            vpdmRing[j] += vphi * dm
            SigdmRing[j] += Sig * dm

SigProf = mRing / (2 * np.pi * rMids[:] * np.diff(rEdges)[:])
SigMassAvg = SigdmRing / mRing
vrMassAvg = vrdmRing / mRing
vpMassAvg = vpdmRing / mRing
Mdot = 2 * np.pi * rMids * vrMassAvg * SigProf
nu = 1e-4
h = 0.1

# %%
plt.clf()
dOmdr = np.gradient((vpMassAvg+rMids)/rMids,rMids)
dvpdr = np.gradient((vpMassAvg+rMids),rMids)
g = 3*np.pi*nu*SigProf*(vpMassAvg+rMids)*rMids
Jdot = Mdot*jProf+g
jProf = rMids*(vpMassAvg+rMids)
plt.plot(rMids,Jdot)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Jdot = (
    rMids * (vpMassAvg+rMids) * Mdot
    +np.sqrt(np.pi)*h* 2*np.pi*rMids*SigProf*nu*np.diff(vpMassAvg+rMids,prepend=vpMassAvg[0]+rMids[0])
    )
plt.clf()
plt.plot(
    rMids, Jdot
)
plt.xlabel(r"$r/R_0$", fontsize=24)
plt.legend()
plt.xlim((0.4, 1.6))
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.clf()
plt.plot(rMids,vpMassAvg+rMids)
plt.plot(rMids,(rMids)**(-1./2))
plt.plot(rMids,(vpMassAvg+rMids)/rMids)
plt.plot(rMids,rMids**(-1.5))
plt.xlabel(r"$r/R_0$",fontsize=24)
plt.legend()
plt.xlim((0.4,1.6))
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## $\dot M$ profiles

# %%
file = "/home/astrosun/jtlaune/athena/work/type2-linext/q1e-4_nu1e-4/fiducial/ppd_cyl.out1.00400.athdf"
ds = yt.load(file)
dd = ds.all_data()
dens_data = np.array(dd["athena_pp", "dens"])
vr_data = np.array(dd["athena_pp", "mom1"]) / dens_data
vphi_data = np.array(dd["athena_pp", "mom2"]) / dens_data
# coords are cell-centered
coords = np.array(dd.fcoords)
# widths of cells
fwidths = np.array(dd.fwidth)
Nr = 128

ristart = 0
riend = Nr + 1
rEdges = np.linspace(0.4, 1.6, riend, endpoint=True)
rMids = (rEdges[:-1] + rEdges[1:]) / 2

mRing = np.zeros(Nr)
vrdmRing = np.zeros(Nr)
SigdmRing = np.zeros(Nr)

for i in range(len(dens_data)):
    Sig = dens_data[i]
    vr = vr_data[i]
    vphi = vphi_data[i]
    r = coords[i, 0]
    phi = coords[i, 1]
    for j in range(Nr+1):
        if rEdges[j] < r <= rEdges[j + 1]:
            rsecn = np.sqrt(r**2 + 1 - 2 * r * np.cos(phi))
            x = r * np.cos(phi)
            y = r * np.sin(phi)

            dr = fwidths[i, 0]
            dphi = fwidths[i, 1]
            dA = r * dr * dphi
            dm = Sig*dA

            mRing[j] += dm
            vrdmRing[j] += vr*dm
            SigdmRing[j] += Sig*dm

SigProf = mRing / (2 * np.pi * rMids[:] * np.diff(rEdges)[:])
vrMassAvg = vrdmRing / mRing
Mdot = 2*np.pi*rMids*vrMassAvg*SigProf

# %%
#fig,ax = plt.subplots(figsize=(7,5))
#ax.plot(rMids,Mdot,label=r"Fid.",c="k")
#ax.plot(rMids,Mdot,label=r"Acc.",c="r")
ax.plot(rMids,Mdot,label=r"I.C.",c="k",ls=":")
ax.set_xlabel(r"$r/R_0$",fontsize=24)
ax.set_ylabel(r"$\dot M(r)$",fontsize=24)
ax.legend()
ax.set_xlim((0.4,1.6))
#ax.set_ylim((-0.03,0))
fig.tight_layout()

# %%
fig

# %%
importlib.reload(athplot)
data_dir = "/home/astrosun/jtlaune/athena/work/type2-linext/no_planet/"
with mpl.rc_context(analytic): fig, ax = plt.subplots(figsize=(8,5))
for iout in range(0,10):
    data_file = os.path.join(data_dir,f"ppd_cyl.out1.{iout:05}.athdf")
    hdf5 = athplot.PpdCylAthhdf5(1e-3,(64,384),data_file,data_dir,force=False)
    profs = hdf5.load()
    ax.plot(profs["rMidpts"],profs["Mdot"],label=f"T={iout*0.5} orb")
    ax.set_xlim((profs["rMidpts"][0],profs["rMidpts"][-1]))
#ax.set_yscale("log")
ax.legend()
ax.set_title(r"$\dot M(r)$",fontsize=24)
ax.set_xlabel(r"$r/R_0$")
fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
0.001/3/np.pi
# Out:
# 0.0001061032953945969

# %% [markdown]
# ## $\dot M$ profiles from interpolation

# %%
def interp(iout):
    data_dir = "/home/astrosun/jtlaune/athena/work/type2-linext/accrete/"
    ds = yt.load(os.path.join(data_dir, f"ppd_cyl.out1.{iout:05}.athdf"))
    dd = ds.all_data()
    r = np.linspace(0.4, 1.6, 2048 + 1)
    p = np.linspace(-np.pi, np.pi, 12288 + 1)
    r = (r[:-1] + r[1:]) / 2
    p = (p[:-1]+p[1:])/2
    RR, PP = np.meshgrid(r, p)
    densInterp = sp.interpolate.griddata(
        (np.array(dd.fcoords[:, 0]), np.array(dd.fcoords[:, 1])),
        np.array(dd["athena_pp", "dens"]),
        (RR.flatten(), PP.flatten()),
        method="nearest",
    )
    vrInterp = sp.interpolate.griddata(
        (np.array(dd.fcoords[:, 0]), np.array(dd.fcoords[:, 1])),
        np.array(dd["athena_pp", "mom1"]) / np.array(dd["athena_pp", "dens"]),
        (RR.flatten(), PP.flatten()),
        method="nearest",
    )
    return (RR, PP, densInterp.reshape(RR.shape), vrInterp.reshape(RR.shape))

# %%
print(192*2**6)
print(1152*2**6)
# Out:
# 12288
# 73728

# %%
RR1, PP1, densInterp1, vrInterp1 = interp(0)
RR2, PP2, densInterp2, vrInterp2 = interp(200)

# %%
print(RR1[0,:].shape)
# Out:
# (1024,)

# %%
print(vrInterp2)
# Out:
# [[-0.00366348 -0.00366348 -0.00366348 ... -0.00094301 -0.00094301
#   -0.00094301]
#  [-0.00366348 -0.00366348 -0.00366348 ... -0.00094301 -0.00094301
#   -0.00094301]
#  [-0.00366348 -0.00366348 -0.00366348 ... -0.00094301 -0.00094301
#   -0.00094301]
#  ...
#  [-0.00366348 -0.00366348 -0.00366348 ... -0.00094301 -0.00094301
#   -0.00094301]
#  [-0.00366348 -0.00366348 -0.00366348 ... -0.00094301 -0.00094301
#   -0.00094301]
#  [-0.00366348 -0.00366348 -0.00366348 ... -0.00094301 -0.00094301
#   -0.00094301]]

# %%
#with mpl.rc_context(analytic): fig,ax = plt.subplots(figsize=(7,5))
#ax.plot(RR1[0,:],2*np.pi*np.mean(RR1*vrInterp1*densInterp1,axis=0),label=r"I.C.",c="k",ls=":")
#ax.plot(RR2[0,:],2*np.pi*np.mean(RR2*vrInterp2*densInterp2,axis=0),label=r"Fid.",c="k")
ax.plot(RR2[0,:],2*np.pi*np.mean(RR2*vrInterp2*densInterp2,axis=0),label=r"Acc.",c="r")
ax.set_xlabel(r"$r/R_0$",fontsize=24)
ax.set_ylabel(r"$\dot M(r)$",fontsize=24)
ax.legend()
ax.set_ylim((-0.03,0))
fig.tight_layout()

# %%
fig

# %%
fig.tight_layout()

# %%
fig, ax = plt.subplots()
cs = ax.pcolormesh(RR2,PP2,densInterp2,vmin=0,vmax=3)
plt.colorbar(cs)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
densInterp = densInterp.reshape(RR.shape)
vrInterp = vrInterp.reshape(RR.shape)

# %%
#fig,ax = plt.subplots()
ax.plot(r,2*np.pi*np.mean(RR*vrInterp*densInterp,axis=1))

# %%
fig

# %%
        dens_data = np.array(dd["athena_pp", "dens"])
        vr_data = np.array(dd["athena_pp", "mom1"]) / dens_data
        vphi_data = np.array(dd["athena_pp", "mom2"]) / dens_data
        # coords are cell-centered
        coords = np.array(dd.fcoords)
        # widths of cells
        fwidths = np.array(dd.fwidth)

# %% [markdown]
# ## Type I

# %% [markdown]
# ## Meeting with Rixin 7/7/23

# %% [markdown]
# 1. use q=5e-5
# 2. use duffel gap profile initial, extend radial domain
# 3. increase nu to 1e-5
# 4. change shape of meshblock to be more square, 2^n
# 5. resolve 2% hill with ~6 cells (only 5 levels of refinement)
#
# **6. non-accreting first without gap profile**
# **Send Rixin better torque plots of the already-ran Type1**

# %%
# duffel gap profile
h_r = 0.05
nu =1e-5
q = 5e-5

a = 1
vk = 1

M = 1/h_r
alpha = nu/(h_r*vk)**2
D = 7*M**1.5/alpha**0.25

def qtil(x):
    return q/(1+D**3*((x/a)**(1./6)-1)**6)**(1./3)

def de(q):
    qc = np.zeros(len(q))
    q_NL = 1.04*M**(-3)
    q_w = q_NL*(alpha*M)**(1./5)
    for i in range(len(qc)):
        if q[i] < q_NL:
            qc[i] = 1
        else:
            qc[i] = (q/q_NL)**(-1./2)+(q/q_w)**3
    return(qc)

def Sig_Sig0(x):
    return 1/(1+(0.45*qtil(x)**2*M**5*de(qtil(x)))/(3*np.pi*alpha))

r = np.linspace(0.4, 3.0, 1000)
with mpl.rc_context(analytic):
    fig, ax = plt.subplots()
ax.plot(r, Sig_Sig0(r), c="r")
ax.set_ylabel(r"$\Sigma/\Sigma_0$ (Duffel+2019)")
ax.set_xlabel(r"$r/R_0$")
ax.axvline(x=0.4, ls="-", c="k")
ax.axvline(x=0.6, ls="--", c="k")
ax.axvline(x=1.6, ls="-", c="k")
ax.axvline(x=1.4, ls="--", c="k")
ax.set_title(
    r"$\alpha=$" + f"{alpha:0.2e}  " + r"$q=$" + f"{q}  " + r"$h=$" + f"{h_r}  "
)
fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Some parameter estimations

# %%
K = 5e-5**2/0.004/0.05**5
1/(1+0.04*K)
# Out:
# 0.9259259259259258

# %%
2**(-1./3)*14/2 # drop level of evolution
# 400 orbits
# Out:
# 5.555903681888698

# %%
1e-5/(0.05**2)
# Out:
# 0.003999999999999999

# %%
(5e-5/3)**(1./3)*.02
# Out:
# 0.0005108729549290355

# %% [markdown]
# ## 2D Density

# %%
importlib.reload(athplot)
ds = athplot.rawDataRestricted("/home/astrosun/jtlaune/Type1BCs/type1_accrete/ppd_cyl.out1.00100.athdf")
fig, ax = plt.subplots(figsize=(4, 7))
for lev in range(7):
    cccs, lds = ds.get_level(lev) # meaning: cell center coordinates, level data set
    meshr, meshphi = np.meshgrid(cccs[0], cccs[1])
    im = ax.pcolormesh(meshr, meshphi, lds['dens'], shading='nearest', cmap="inferno", norm=colors.LogNorm(vmin=0.1, vmax=3))
cb = plt.colorbar(im)
ax.set_ylabel(r"$\phi$",fontsize=24)
ax.set_xlabel(r"$r$",fontsize=24)
fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
importlib.reload(athplot)
ds = athplot.rawDataRestricted("/home/astrosun/jtlaune/Type1BCs/type1_fiducial/ppd_cyl.out1.00100.athdf")
fig, ax = plt.subplots(figsize=(4, 7))
for lev in range(7):
    cccs, lds = ds.get_level(lev) # meaning: cell center coordinates, level data set
    meshr, meshphi = np.meshgrid(cccs[0], cccs[1])
    im = ax.pcolormesh(meshr, meshphi, lds['dens'], shading='nearest', cmap="inferno", norm=colors.LogNorm(vmin=0.1, vmax=3))
cb = plt.colorbar(im)
ax.set_ylabel(r"$\phi$",fontsize=24)
ax.set_xlabel(r"$r$",fontsize=24)
fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Density profiles

# %% [markdown]
# ### Accreting

# %%
data_dir = "/home/astrosun/jtlaune/Type1BCs/type1_accrete"
outdir = "/home/astrosun/jtlaune/Type1Outs/accrete"
for iout in [0,10,20,50,90,100]:
    data_file = os.path.join(data_dir,f"ppd_cyl.out1.{iout:05}.athdf")
    hdf5 = athplot.PpdCylAthhdf5(1e-3,(192,1152),data_file,outdir)
    profs = hdf5.load()

# %%
data_dir = "/home/astrosun/jtlaune/Type1BCs/type1_accrete"
outdir = "/home/astrosun/jtlaune/Type1Outs/accrete"
with mpl.rc_context(analytic): fig, ax = plt.subplots()
for iout in [0,10,20,90,100]:
    data_file = os.path.join(data_dir,f"ppd_cyl.out1.{iout:05}.athdf")
    hdf5 = athplot.PpdCylAthhdf5(1e-3,(192,1152),data_file,outdir)
    profs = hdf5.load()
    ax.plot(profs["rMidpts"],profs["Sig"],label=f"{iout} orbits")
ax.set_yscale("log")
ax.legend()
ax.set_xlabel(r"$r/R_0$")
ax.set_ylabel(r"$\Sigma/\Sigma_0$")
fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Fiducial

# %%
mins = np.zeros(81)
for i,iout in enumerate(np.arange(81)*10):
    data_file = os.path.join(data_dir,f"ppd_cyl.out1.{iout:05}.athdf")
    hdf5 = athplot.PpdCylAthhdf5(1e-3,(256,1536),data_file,outdir)
    profs = hdf5.load()
    mins[i] = np.min(profs["Sig"])

# %%
def fitFunc(t, A, tau, b):
    return A * np.exp(t/tau) + b


popt, pcov = sp.optimize.curve_fit(
    fitFunc, np.arange(20, 81) * 10, mins[20:], [1, -100, 1]
)
print(popt)
# Out:
# [ 2.72198132e-01 -3.20243433e+02  6.00257573e-01]

# %%
1400/320
# Out:
# 4.375

# %%
with mpl.rc_context(analytic): fig, ax = plt.subplots(figsize=(7,5))
ax.scatter(np.arange(20,81)*10,mins[20:])
ax.plot(np.arange(20,201)*10, fitFunc(np.arange(20,201)*10,popt[0],popt[1],popt[2]),c="c")
ax.plot(np.arange(20,161)*10, fitFunc(np.arange(20,161)*10,popt[0],popt[1],popt[2]),c="orange")
ax.set_yscale("log")
fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
data_dir = "/home/astrosun/jtlaune/Type1BCs/type1_fiducial_400"
outdir = "/home/astrosun/jtlaune/Type1Outs/no_accrete"
for iout in [0,100,400,700,750,760,770,780,790,800]:
    data_file = os.path.join(data_dir,f"ppd_cyl.out1.{iout:05}.athdf")
    hdf5 = athplot.PpdCylAthhdf5(1e-3,(256,1536),data_file,outdir)
    profs = hdf5.load()

# %%
with mpl.rc_context(analytic): fig, ax = plt.subplots()
for iout in [0,100,400,700,750,760,770,780,790,800]:
    data_file = os.path.join(data_dir,f"ppd_cyl.out1.{iout:05}.athdf")
    hdf5 = athplot.PpdCylAthhdf5(1e-3,(256,1536),data_file,outdir)
    profs = hdf5.load()
    ax.plot(profs["rMidpts"],profs["Sig"],label=f"{iout} orbits")
ax.set_yscale("log")
ax.legend()
ax.set_xlabel(r"$r/R_0$")
ax.set_ylabel(r"$\Sigma/\Sigma_0$")
fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Reducing the history file

# %%
data = np.loadtxt("/home/astrosun/jtlaune/Type1BCs/type1_fiducial_400/ppd_cyl.hst")
data.shape
data_reduced = {}
for i in range(16):
    data_reduced[i] = athplot.movingAverage(data[:,i],1)[::1000]

np.save("/home/astrosun/jtlaune/Type1Outs/no_accrete/reducedHst.npy",data_reduced)

# %%
hstNoAcc = np.load("/home/astrosun/jtlaune/Type1Outs/no_accrete/reducedHst.npz.npy",allow_pickle=True).item()
hstAcc = np.load("/home/astrosun/jtlaune/Type1Outs/accrete/reducedHst.npz.npy",allow_pickle=True).item()

# %%
hstAcc[0][-1]/(2*np.pi)
# Out:
# 99.99884611298486

# %%
print(5e-5**2/0.05**2)
print(hstNoAcc[12][-1])
# Out:
# 9.999999999999997e-07
# 4.065799998898001e-06

# %% [markdown]
# ## Torque

# %%
with mpl.rc_context(analytic): fig, ax = plt.subplots()
ax.plot(hstNoAcc[0]/(2*np.pi),hstNoAcc[12],label="Fiducial")
ax.plot(hstAcc[0]/(2*np.pi),hstAcc[12]+hstAcc[10]+hstAcc[15],label="Accreting")
ax.set_yscale("symlog",linthresh=1e-7)
ax.legend()
ax.set_ylabel("Torque [code units]")
ax.set_xlabel("T [orbits]")
fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# /home/astrosun/jtlaune/opt/miniconda3/envs/py311/lib/python3.11/site-packages/ipympl/backend_nbagg.py:279: UserWarning: All values for SymLogScale are below linthresh, making it effectively linear. You likely should lower the value of linthresh.
#   self.manager.handle_json(content)

# %% [markdown]
# ## Disk Mass

# %%
with mpl.rc_context(analytic): fig, ax = plt.subplots()
ax.plot(hstNoAcc[0]/(2*np.pi),hstNoAcc[12],label="Fiducial")
ax.plot(hstAcc[0]/(2*np.pi),hstAcc[12]+hstAcc[10]+hstAcc[15],label="Accreting")
ax.set_yscale("symlog",linthresh=1e-7)
ax.legend()
ax.set_ylabel("Torque [code units]")
ax.set_xlabel("T [orbits]")
fig.tight_layout()
